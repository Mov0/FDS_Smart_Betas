# %%
import pandas as pd
import numpy as np
from pandas import DataFrame

# %%
# Read returns to calculate the variance of the returns and create empty dataframe
df_Returns = pd.read_pickle("UsableData/Returns.pkl").T
df_Variance = DataFrame()

# %%
# Calculate variance of returns for each year and stock
years = df_Returns.index.year.unique()
for year in years:
    returns = df_Returns[(df_Returns.index >= f"{year}-01-01") & (df_Returns.index <= f"{year}-12-31")]
    for ric in returns.columns:
        df_Variance.at[ric, year] = np.var(returns[ric])
df_Variance.head(5)
# Out:
#                 1994       1995       1996        1997        1998  \
# BAYGn.DE   27.277955  10.640167  33.616449   65.208538   84.213922
# DTEGn.DE         NaN        NaN   3.794764   76.764409   83.917071
# MBGn.DE   476.653075  36.298345  27.112524   80.901484  110.622961
# ALVG.DE    26.108533  26.787488  12.544280  109.110125   81.846124
# SIEGn.DE   35.540292   9.241408  14.552579   88.154216  164.178416
#
#                 1999        2000        2001        2002        2003  ...  \
# BAYGn.DE   50.606431  101.453746   75.299604  157.435071  252.742107  ...
# DTEGn.DE  240.927008  153.665688  199.345848  301.718945   53.413115  ...
# MBGn.DE   103.749032   63.244981  209.605330   96.598755   79.499738  ...
# ALVG.DE    70.860344   49.283757   44.183541  222.090548  539.614641  ...
# SIEGn.DE   98.670381  189.744805  266.289133  282.026996   85.539963  ...
#
#                2012       2013       2014       2015       2016       2017  \
# ...

# %%
# Save dataframe
df_Variance.to_pickle("UsableData/Variance.pkl")
