# %%
import pandas as pd
import numpy as np
data = pd.read_csv('IDs.csv')
data
# Out:
#                           Name (or Code)                   RIC          ISIN  \
# 0                               Bayer AG              BAYGn.DE  DE000BAY0017
# 1                    Deutsche Telekom AG              DTEGn.DE  DE0005557508
# 2                 Mercedes-Benz Group AG               MBGn.DE  DE0007100000
# 3                             Allianz SE               ALVG.DE  DE0008404005
# 4                             Siemens AG              SIEGn.DE  DE0007236101
# ...                                  ...                   ...           ...
# 1715             Tacitus Capital Ord Shs            TCP.SG^C16  DE000A0MFXQ0
# 1716  DWH Deutsche Werte Holding Ord Shs            DWH.VI^C20  DE000A0B6NF2
# 1717                   Signature Ord Shs           SIGN.VI^H21  DE000A2DAMG0
# 1718       Landw Rentenbank Common Stock  DE016013382=ISMA^D10           NaN
# 1719                      Innogy Ord Shs            IGY.BN^F20  DE000A2AADD2
#
#      CUSIP/CINS  Type of Equity                             Exchange  \
# 0     D0712D163  Ordinary Share                                Xetra
# 1     D2035M136  Ordinary Share                                Xetra
# 2     D1668R123  Ordinary Share                                Xetra
# 3     D03080112  Ordinary Share                                Xetra
# 4     D69671218  Ordinary Share                                Xetra
# ...         ...             ...                                  ...
# 1715  D8295Z105  Ordinary Share             Stuttgart Stock Exchange
# 1716  D0R85D106  Ordinary Share  Vienna Stock Exchange - Cash Market
# 1717  D3R8BQ104  Ordinary Share  Vienna Stock Exchange - Cash Market
# 1718  undefined  Ordinary Share                                  NaN
# 1719  D3R8BR110  Ordinary Share                 Berne Stock Exchange
#
#      Country of Issuer
# 0              Germany
# 1              Germany
# 2              Germany
# 3              Germany
# 4              Germany
# ...                ...
# 1715           Germany
# 1716           Germany
# 1717           Germany
# 1718           Germany
# 1719           Germany
#
# [1720 rows x 7 columns]

# %%
nan_count = data["RIC"].isna().sum()

# Print the result
print("Number of NaN values in RIC column:", nan_count)
# Out:
# Number of NaN values in RIC column: 0
