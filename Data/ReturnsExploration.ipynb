# %%
import pandas as pd
import numpy as np
data = pd.read_csv('Returns.csv')
data
# Out:
#                        RIC  31/01/1994  28/02/1994  31/03/1994  30/04/1994  \
# 0                 BAYGn.DE    0.674764   -2.144772    2.630137    8.094119
# 1                 DTEGn.DE         NaN         NaN         NaN         NaN
# 2                  MBGn.DE   -2.906287   -0.794136    5.541872    5.507585
# 3                  ALVG.DE   -2.962206  -10.456140    0.783699    1.399689
# 4                 SIEGn.DE   -8.691824   -5.565505  475.504883    7.168459
# ...                    ...         ...         ...         ...         ...
# 1715            TCP.SG^C16         NaN         NaN         NaN         NaN
# 1716            DWH.VI^C20         NaN         NaN         NaN         NaN
# 1717           SIGN.VI^H21         NaN         NaN         NaN         NaN
# 1718  DE016013382=ISMA^D10         NaN         NaN         NaN         NaN
# 1719            IGY.BN^F20         NaN         NaN         NaN         NaN
#
#       31/05/1994  30/06/1994  31/07/1994  31/08/1994  30/09/1994  ...  \
# 0      -6.985014   -5.789186    5.130435    4.494072   -9.894459  ...
# 1            NaN         NaN         NaN         NaN         NaN  ...
# 2      76.313770   -9.055225   11.341345    3.722084  -11.303828  ...
# 3      -3.865612   -3.512397    5.310493    0.528670   -9.385113  ...
# 4      -6.688963   -7.096774    5.169753    3.008070  -10.185185  ...
# ...          ...         ...         ...         ...         ...  ...
# 1715         NaN         NaN         NaN         NaN         NaN  ...
# 1716         NaN         NaN         NaN         NaN         NaN  ...
# 1717         NaN         NaN         NaN         NaN         NaN  ...
# 1718         NaN         NaN         NaN         NaN         NaN  ...
# 1719         NaN         NaN         NaN         NaN         NaN  ...
#
#       31/03/2021  30/04/2021  31/05/2021  30/06/2021  31/07/2021  31/08/2021  \
# 0       7.661612    3.472655   -4.347826   -0.524476   -1.796524   -6.253728
# 1      14.238190   -3.439952    6.212500    4.813464   -1.717943    2.867588
# 2      14.732075   -0.832937    2.862930   -1.142182   -0.026560   -5.127524
# 3       8.633634   -0.299470    4.054583   -2.390346   -0.142653   -5.247619
# 4       9.392093   -0.842857   -4.451808    0.738842   -1.526718    7.037544
# ...          ...         ...         ...         ...         ...         ...
# 1715         NaN         NaN         NaN         NaN         NaN         NaN
# 1716         NaN         NaN         NaN         NaN         NaN         NaN
# 1717  -40.000000    8.333333    1.538462   21.212121   -6.250000    0.000000
# 1718         NaN         NaN         NaN         NaN         NaN         NaN
# 1719         NaN         NaN         NaN         NaN         NaN         NaN
#
#       30/09/2021  31/10/2021  30/11/2021  31/12/2021
# 0      -0.296956    3.542176   -8.526813    5.570530
# 1      -3.398490   -7.576454   -3.047643    4.567616
# 2       7.420891   11.757039   -3.195708   -2.771378
# 3      -2.080611    3.238555   -4.330102    7.903762
# 4       0.766828   -1.155581    0.712860    8.069083
# ...          ...         ...         ...         ...
# 1715         NaN         NaN         NaN         NaN
# 1716         NaN         NaN         NaN         NaN
# 1717         NaN         NaN         NaN         NaN
# 1718         NaN         NaN         NaN         NaN
# 1719         NaN         NaN         NaN         NaN
#
# [1720 rows x 337 columns]

# %%
nan_count = data["RIC"].isna().sum()

# Print the result
print("Number of NaN values in RIC column:", nan_count)
# Out:
# Number of NaN values in RIC column: 0
