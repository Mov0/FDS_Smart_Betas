# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Data/IDs.csv')
data.head(5)
# Out:
#            Name (or Code)       RIC          ISIN CUSIP/CINS  Type of Equity  \
# 0                Bayer AG  BAYGn.DE  DE000BAY0017  D0712D163  Ordinary Share
# 1     Deutsche Telekom AG  DTEGn.DE  DE0005557508  D2035M136  Ordinary Share
# 2  Mercedes-Benz Group AG   MBGn.DE  DE0007100000  D1668R123  Ordinary Share
# 3              Allianz SE   ALVG.DE  DE0008404005  D03080112  Ordinary Share
# 4              Siemens AG  SIEGn.DE  DE0007236101  D69671218  Ordinary Share
#
#   Exchange Country of Issuer
# 0    Xetra           Germany
# 1    Xetra           Germany
# 2    Xetra           Germany
# 3    Xetra           Germany
# 4    Xetra           Germany

# %%
data[data.isna().any(axis=1)]
# Out:
#                                        Name (or Code)                   RIC  \
# 915                              DZ Bank Common Stock          SGZGpg.F^J03
# 1356                    Dresdner Bank AG Common Stock          DRSDn.PA^I98
# 1361                                  Hach AG Ord Shs            HAHG.F^H92
# 1365                     Rheinland Pfalz Bank Ord Shs            LRPG.F^G92
# 1382                       Blaue Quellen Common Stock           BQUM.CD^K00
# 1383                      Schmalbach Lub Common Stock           SMLB.CD^K00
# 1470                                  AGIV AG Ord Shs           AFIGe.F^G02
# 1666  Deutsche Genossenschafts Hypothekenbank Ord Shs            DGHG.H^G99
# 1670                  Hypothekenbank in Essen Ord Shs            HIEG.D^D96
# 1674             GZB-Bank Genossenschaftliche Ord Shs           GBSG.SG^D96
# 1675           Dexia Kommunalbank Deutschland Ord Shs            HIBG.H^D96
# ...
